# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100)
data
# Out:
# array([47, 26, 31, 13, 39, 43, 12,  4, 34, 43,  3, 49, 42, 13,  9, 27,  9,
#        49, 32, 44, 35, 21, 27,  4,  6, 49, 45, 36,  9, 18,  2, 48, 10, 17,
#        12, 16, 34, 17, 20,  2, 47, 12, 33,  1, 38, 10, 34, 16, 34, 30, 39,
#        36, 34, 15, 36, 12, 39, 47, 20, 29, 49, 19, 37, 10, 39, 33,  4, 12,
#        41, 44, 32, 36, 33, 44, 39,  2, 39, 39, 46, 17, 41,  3, 28, 40, 33,
#         5,  2,  8, 31, 42, 33, 37, 46,  8, 41, 28, 40,  3, 20, 11])

# %% [markdown]
# ## Histograma

# %%
plt.hist(data, bins=10,width=5, histtype='bar')
plt.show()

# %%
plt.hist(data, bins=10, histtype='step')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
data2 = np.append(data,200)
plt.boxplot(data2, vert=False, patch_artist=True,notch=True,showfliers=False)
plt.show()

# %% [markdown]
# ## Scatter

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N))** 2
colors = np.random.rand(N)

# %%
plt.scatter(x,y,s=area,c=colors,marker='o',alpha= 0.5)
plt.show()
